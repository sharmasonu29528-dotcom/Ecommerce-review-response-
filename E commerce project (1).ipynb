# %%
pip install langchain langchain-core langchain-groq langchain-community
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.3.11)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.12/dist-packages (1.4.8)
# Requirement already satisfied: langchain-groq in /usr/local/lib/python3.12/dist-packages (1.1.3)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (0.4.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.9.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.16.2)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in /usr/local/lib/python3.12/dist-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.7.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (15.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.6.17)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/ecommerce data.csv')
df.head()
# Out:
#    Review_ID Customer_ID                      Email         Product  \
# 0          1   CUST00001    customer00001@gmail.com      Laptop Bag
# 1          2   CUST00002    customer00002@gmail.com  Wireless Mouse
# 2          3   CUST00003    customer00003@gmail.com     Smart Watch
# 3          4   CUST00004  customer00004@outlook.com     Smart Watch
# 4          5   CUST00005  customer00005@hotmail.com       Face Wash
#
#       Category Brand    Price  Rating               Review Review_Date  \
# 0  Accessories  Nike  1122.01     4.0  Happy with purchase  2024-09-27
# 1  Electronics  Puma   451.09     1.0             Not good  2024-07-27
# 2  Electronics  Boat   843.17     NaN  Happy with purchase  2024-01-11
# 3  Electronics  Sony  1240.67     4.0  Happy with purchase  2024-12-02
# 4       Beauty  Dell  2631.84     5.0  Happy with purchase  2024-06-11
#
#   Verified_Purchase  Helpful_Votes Sentiment
# 0               Yes             50  Positive
# 1                No              2  Negative
# 2                No             10  Positive
# 3               Yes              7  Positive
# 4                No             24  Positive

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Review_ID              0
# Customer_ID            0
# Email                  0
# Product                0
# Category               0
# Brand                 87
# Price                  0
# Rating                91
# Review               141
# Review_Date            0
# Verified_Purchase      0
# Helpful_Votes          0
# Sentiment              0
# dtype: int64

# %%
df.dtypes
# Out:
# Review_ID              int64
# Customer_ID           object
# Email                 object
# Product               object
# Category              object
# Brand                 object
# Price                float64
# Rating               float64
# Review                object
# Review_Date           object
# Verified_Purchase     object
# Helpful_Votes          int64
# Sentiment             object
# dtype: object

# %%
df['Email'] = df['Email'].str.split('@').str[0]

# %%
df['Email'].value_counts()
# Out:
# Email
# customer00050    2
# customer00049    2
# customer00048    2
# customer00047    2
# customer00046    2
#                 ..
# customer01036    1
# customer01037    1
# customer01038    1
# customer01039    1
# customer01028    1
# Name: count, Length: 3000, dtype: int64

# %%
num_cols = df.dtypes[df.dtypes!=object].index
cat_cols = df.dtypes[df.dtypes==object].index
print(num_cols)
print(cat_cols)
# Out:
# Index(['Review_ID', 'Price', 'Rating', 'Helpful_Votes'], dtype='object')
# Index(['Customer_ID', 'Email', 'Product', 'Category', 'Brand', 'Review',
#        'Review_Date', 'Verified_Purchase', 'Sentiment'],
#       dtype='object')

# %%
def count_per_null(data):  # data is df
    nv = data.isnull().sum()
    nv = nv[nv >0]    # include only those column where null values are more than 0
    nv_df = pd.DataFrame({'Feature':nv.index,'Null_Count':nv.values,
                          'Null%': (nv.values/data.shape[0])*100})
    return nv_df

# %%
nv_df = count_per_null(df)
nv_df
# Out:
#   Feature  Null_Count     Null%
# 0   Brand          87  2.852459
# 1  Rating          91  2.983607
# 2  Review         141  4.622951

# %%
for i in num_cols:
    df[i] = df[i].fillna(df[i].mean())

# %%
for i in cat_cols:
    df[i] = df[i].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# Review_ID            0
# Customer_ID          0
# Email                0
# Product              0
# Category             0
# Brand                0
# Price                0
# Rating               0
# Review               0
# Review_Date          0
# Verified_Purchase    0
# Helpful_Votes        0
# Sentiment            0
# dtype: int64

# %%
a1 = df[num_cols].describe(percentiles= [0.01,0.02,0.05,0.97,0.98,0.99]).T
a1 = a1.iloc[:,3:]
a1
# Out:
#                   min        1%       2%       5%      50%        97%  \
# Review_ID        1.00   31.4900   61.980  153.450  1525.50  2958.5300
# Price          250.98  297.6588  333.678  478.805  2657.54  4873.7956
# Rating           1.00    1.0000    1.000    1.000     3.00     5.0000
# Helpful_Votes    0.00    0.0000    1.000    2.000    25.00    49.0000
#
#                      98%       99%      max
# Review_ID      2989.0200  3019.510  3050.00
# Price          4917.3594  4957.282  4998.28
# Rating            5.0000     5.000     5.00
# Helpful_Votes    50.0000    50.000    50.00

# %%
df['Review_ID'] = np.where(df['Review_ID'] <31.4900 ,31.4900, df['Review_ID'])
df['Review_ID'] = np.where(df['Review_ID'] > 3019.510, 3019.510, df['Review_ID'])

# %%
df['Price'] = np.where(df['Price'] <297.6588 ,297.6588, df['Price'])
df['Price'] = np.where(df['Price'] > 4957.282, 4957.282, df['Price'])

# %%
a1 = df[num_cols].describe(percentiles= [0.01,0.02,0.05,0.97,0.98,0.99]).T
a1 = a1.iloc[:,3:]
a1
# Out:
#                     min          1%       2%       5%      50%        97%  \
# Review_ID       31.4900   31.739900   61.980  153.450  1525.50  2958.5300
# Price          297.6588  297.688788  333.678  478.805  2657.54  4873.7956
# Rating           1.0000    1.000000    1.000    1.000     3.00     5.0000
# Helpful_Votes    0.0000    0.000000    1.000    2.000    25.00    49.0000
#
#                      98%         99%       max
# Review_ID      2989.0200  3019.26010  3019.510
# Price          4917.3594  4956.98212  4957.282
# Rating            5.0000     5.00000     5.000
# Helpful_Votes    50.0000    50.00000    50.000

# %%
a1 = df[num_cols].describe(percentiles= [0.01,0.02,0.05,0.97,0.98,0.99]).T
a1 = a1.iloc[:,3:]
a1
# Out:
#                     min          1%       2%       5%      50%        97%  \
# Review_ID       31.4900   31.739900   61.980  153.450  1525.50  2958.5300
# Price          297.6588  297.688788  333.678  478.805  2657.54  4873.7956
# Rating           1.0000    1.000000    1.000    1.000     3.00     5.0000
# Helpful_Votes    0.0000    0.000000    1.000    2.000    25.00    49.0000
#
#                      98%         99%       max
# Review_ID      2989.0200  3019.26010  3019.510
# Price          4917.3594  4956.98212  4957.282
# Rating            5.0000     5.00000     5.000
# Helpful_Votes    50.0000    50.00000    50.000

# %%
df['Rating'] = pd.to_numeric(df['Rating'].astype(int))

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 3    678
# 5    621
# 1    610
# 2    574
# 4    567
# Name: count, dtype: int64

# %%
df['Rating_Type'] = np.where(df['Rating'].isin([1,2]),'Critical','Moderate or Good')

# %%
df['Rating_Type'].value_counts()
# Out:
# Rating_Type
# Moderate or Good    1866
# Critical            1184
# Name: count, dtype: int64

# %%
critical_df = df[df['Rating_Type']=='Critical']
critical_df.shape
# Out:
# (1184, 14)

# %%
from collections import Counter

# %%
def most_common_complain_keywords(data):
  keyword_counter = Counter(data['Review'])
  return keyword_counter

# %%
critical_keyword = most_common_complain_keywords(critical_df)
critical_keyword
# Out:
# Counter({'Not good': 199,
#          'Waste of money': 197,
#          'Poor quality': 171,
#          'not good': 22,
#          'Product damaged': 197,
#          'waste of money': 22,
#          'Unknown': 52,
#          'very disappointed': 10,
#          'Very disappointed': 187,
#          ' Poor quality ': 17,
#          ' Product damaged ': 17,
#          ' Very disappointed ': 17,
#          ' Waste of money ': 18,
#          'poor quality': 9,
#          ' Not good ': 22,
#          'product damaged': 21,
#          ' very disappointed ': 1,
#          ' not good ': 2,
#          ' waste of money ': 1,
#          ' poor quality ': 1,
#          ' product damaged ': 1})

# %%
crit_keyword_df = pd.DataFrame(critical_keyword.items(),columns=['Keywords','Count'])
crit_keyword_df
# Out:
#                Keywords  Count
# 0              Not good    199
# 1        Waste of money    197
# 2          Poor quality    171
# 3              not good     22
# 4       Product damaged    197
# 5        waste of money     22
# 6               Unknown     52
# 7     very disappointed     10
# 8     Very disappointed    187
# 9         Poor quality      17
# 10     Product damaged      17
# 11   Very disappointed      17
# 12      Waste of money      18
# 13         poor quality      9
# 14            Not good      22
# 15      product damaged     21
# 16   very disappointed       1
# 17            not good       2
# 18      waste of money       1
# 19        poor quality       1
# 20     product damaged       1

# %%
import plotly.express as px

# %%
fig = px.bar(crit_keyword_df,x='Keywords',y='Count',text='Count')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="17f54139-f98e-4206-8c63-b89dc3301261" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17f54139-f98e-4206-8c63-b89dc3301261")) {                    Plotly.newPlot(                        "17f54139-f98e-4206-8c63-b89dc3301261",                        [{"alignmentgroup":"True","hovertemplate":"Keywords=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[199.0,197.0,171.0,22.0,197.0,22.0,52.0,10.0,187.0,17.0,17.0,17.0,18.0,9.0,22.0,21.0,1.0,2.0,1.0,1.0,1.0],"textposition":"auto","x":["Not good","Waste of money","Poor quality","not good","Product damaged","waste of money","Unknown","very disappointed","Very disappointed"," Poor quality "," Product damaged "," Very disappointed "," Waste of money ","poor quality"," Not good ","product damaged"," very disappointed "," not good "," waste of money "," poor quality "," product damaged "],"xaxis":"x","y":[199,197,171,22,197,22,52,10,187,17,17,17,18,9,22,21,1,2,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solid ...

# %%
def topK_most_crit_reviews(data,K):
  top3_crit_reviews = data.sort_values(by='Count',ascending=False).head(K)
  return top3_crit_reviews

# %%
topK_most_crit_reviews(crit_keyword_df,3)
# Out:
#           Keywords  Count
# 0         Not good    199
# 1   Waste of money    197
# 4  Product damaged    197

# %%
def extract_cust_id_and_review(data, customer_id):
    text = data.loc[data['Customer_ID'] == customer_id, 'Review'].values[0]
    return text

# %%
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser
import os

# %%
import os
from google.colab import userdata
os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile",   # or another Groq-supported model
    temperature=0.72,
    api_key=os.environ["GROQ_API_KEY"]
)

parser = StrOutputParser()

# %%
prompt  = PromptTemplate.from_template("""
Role
You are an experienced Customer Support Agent for an e-commerce company.

Task
Generate a short, personalized, professional, and empathetic apology email for the customer based on the provided Customer ID and Review.

Inputs
Customer ID: {Cust_ID}
Customer Review: {Review}
Instructions
Address the customer using their Customer ID.
Begin with a sincere apology.
Specifically acknowledge the complaint mentioned in the review. Do not generate a generic apology.
Show empathy and understanding.
Briefly assure the customer that the issue will be investigated and steps will be taken to prevent it from happening again.
If applicable, mention that the customer can contact the support team for additional assistance.
End the email with a polite closing and appreciation for the customer's feedback.
Keep the email between 80 and 120 words.
Maintain a warm, respectful, and professional tone.
Do not invent order details, dates, refund amounts, or promises that are not supported by the review.
Output Format

Subject: We're Sorry About Your Experience

Dear {Cust_ID},

<Generate a personalized apology email here based on the review.>

Best Regards,

Customer Support Team

""")

# %%
chain = prompt | llm | parser

text_review = extract_cust_id_and_review(df,'CUST00005')
res = chain.invoke({
    "Cust_ID": "CUST00005",
    "Review": text_review
})

print(res)
# Out:
# Subject: We're Sorry About Your Experience
#
# Dear CUST00005,
#
# We apologize, but it seems there's no complaint mentioned in your review. You've stated you're happy with your purchase. We appreciate your positive feedback and are glad to hear that our service met your expectations.
#
# Best Regards,
# Customer Support Team
